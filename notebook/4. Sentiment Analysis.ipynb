# %% [markdown]
# # 1. Library Installation

# %%
# !pip install -q pandas
# !pip install -q vaderSentiment

# %% [markdown]
# # 2. Import Dataset

# %%
import pandas as pd

file_path = '../dataset/dataset.csv'
df = pd.read_csv(file_path)

# %%
df
# Out:
#                   app                                            content  \
# 0      Disaster Alert  Working as a Public Health Nurse I get to resp...
# 1      Disaster Alert  Nice to have before traveling to unknown terri...
# 2      Disaster Alert  I like! I'm trying to find anything about tsun...
# 3      Disaster Alert  good to have but what options are expected in ...
# 4      Disaster Alert  Shows hazards all right but refuses to send no...
# ...               ...                                                ...
# 27641      Earthquake  It works quite well even anticipates some othe...
# 27642      Earthquake                     This application is very good.
# 27643      Earthquake  Data from earthquakes in Chile in the last 24 ...
# 27644      Earthquake  This is as good as earthquake apps can go. Thi...
# 27645      Earthquake  Delivers everything described in the write-up ...
#
#        score  sentiment_score sentiment
# 0          5           0.1007  positive
# 1          5           0.4215  positive
# 2          5           0.4738  positive
# 3          5           0.2382  positive
# 4          2          -0.5588  negative
# ...      ...              ...       ...
# 27641      5           0.7264  positive
# 27642      5           0.4927  positive
# 27643      2           0.0000  positive
# 27644      5           0.8481  positive
# 27645      5           0.0000  positive
#
# [27646 rows x 5 columns]

# %% [markdown]
# # 3. Sentiment Analysis

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import time

analyzer = SentimentIntensityAnalyzer()
sentiment_score_list = []

start_time = time.time()
for i, sentence in enumerate(df['content'], 1):
    vs = analyzer.polarity_scores(sentence)
    sentiment_score_list.append(vs['compound'])

    # Print progress every 500 sentences
    if i % 1000 == 0:
        elapsed_time = time.time() - start_time
        print(f"Processed {i} sentences in {elapsed_time:.2f} seconds.")

# Total time taken
total_time = time.time() - start_time
print(f"Total time taken: {total_time:.2f} seconds.")
# Out:
# Processed 500 sentences in 0.09 seconds.
# Processed 1000 sentences in 0.14 seconds.
# Processed 1500 sentences in 0.20 seconds.
# Processed 2000 sentences in 0.26 seconds.
# Processed 2500 sentences in 0.30 seconds.
# Processed 3000 sentences in 0.35 seconds.
# Processed 3500 sentences in 0.40 seconds.
# Processed 4000 sentences in 0.45 seconds.
# Processed 4500 sentences in 0.50 seconds.
# Processed 5000 sentences in 0.56 seconds.
# Processed 5500 sentences in 0.62 seconds.
# Processed 6000 sentences in 0.66 seconds.
# Processed 6500 sentences in 0.77 seconds.
# Processed 7000 sentences in 0.87 seconds.
# Processed 7500 sentences in 0.93 seconds.
# Processed 8000 sentences in 0.98 seconds.
# Processed 8500 sentences in 1.02 seconds.
# Processed 9000 sentences in 1.07 seconds.
# Processed 9500 sentences in 1.12 seconds.
# Processed 10000 sentences in 1.18 seconds.
# Processed 10500 sentences in 1.24 seconds.
# Processed 11000 sentences in 1.30 seconds.
# Processed 11500 sentences in 1.38 seconds.
# Processed 12000 sentences in 1.47 seconds.
# Processed 12500 sentences in 1.53 seconds.
# Processed 13000 sentences in 1.58 seconds.
# Processed 13500 sentences in 1.66 seconds.
# Processed 14000 sentences in 1.70 seconds.
# Processed 14500 sentences in 1.77 seconds.
# Processed 15000 sentences in 1.82 seconds.
# Processed 15500 sentences in 1.94 seconds.
# Processed 16000 sentences in 2.04 seconds.
# Processed 16500 sentences in 2.15 seconds.
# Processed 17000 sentences in 2.27 seconds.
# Processed 17500 sentences in 2.42 seconds.
# Processed 18000 sentences in 2.56 seconds.
# Processed 18500 sentences in 2.66 seconds.
# Processed 19000 sentences in 2.79 seconds.
# Processed 19500 sentences in 2.91 seconds.
# Processed 20000 sentences in 3.03 seconds.
# Processed 20500 sentences in 3.14 seconds.
# Processed 21000 sentences in 3.21 seconds.
# Processed 21500 sentences in 3.28 seconds.
# Processed 22000 sentences in 3.46 seconds.
# Processed 22500 sentences in 3.61 seconds.
# Processed 23000 sentences in 3.69 seconds.
# Processed 23500 sentences in 3.93 seconds.
# Processed 24000 sentences in 4.02 seconds.
# Processed 24500 sentences in 4.08 seconds.
# Processed 25000 sentences in 4.15 seconds.
# Processed 25500 sentences in 4.26 seconds.
# Processed 26000 sentences in 4.50 seconds.
# Processed 26500 sentences in 4.74 seconds.
# Processed 27000 sentences in 4.90 seconds.
# Processed 27500 sentences in 4.98 seconds.
# Total time taken: 5.00 seconds.

# %%
df['sentiment_score'] = sentiment_score_list
df['sentiment'] = df['sentiment_score'].apply(lambda score: 'positive' if score >= 0 else 'negative')

# %%
df
# Out:
#                   app                                            content  \
# 0      Disaster Alert  Working as a Public Health Nurse I get to resp...
# 1      Disaster Alert  Nice to have before traveling to unknown terri...
# 2      Disaster Alert  I like! I'm trying to find anything about tsun...
# 3      Disaster Alert  good to have but what options are expected in ...
# 4      Disaster Alert  Shows hazards all right but refuses to send no...
# ...               ...                                                ...
# 27643      Earthquake  It works quite well even anticipates some othe...
# 27644      Earthquake                     This application is very good.
# 27645      Earthquake  Data from earthquakes in Chile in the last 24 ...
# 27646      Earthquake  This is as good as earthquake apps can go. Thi...
# 27647      Earthquake  Delivers everything described in the write-up ...
#
#        score  sentiment_score sentiment
# 0          5           0.1007  positive
# 1          5           0.4215  positive
# 2          5           0.4738  positive
# 3          5           0.2382  positive
# 4          2          -0.5588  negative
# ...      ...              ...       ...
# 27643      5           0.7264  positive
# 27644      5           0.4927  positive
# 27645      2           0.0000  positive
# 27646      5           0.8481  positive
# 27647      5           0.0000  positive
#
# [27648 rows x 5 columns]

# %%
df.groupby(['score', 'sentiment']).count()
# Out:
#                    app  content  sentiment_score
# score sentiment
# 0     positive       2        2                2
# 1     negative    2843     2843             2843
#       positive    2808     2808             2808
# 2     negative     972      972              972
#       positive    1278     1278             1278
# 3     negative     770      770              770
#       positive    1683     1683             1683
# 4     negative     485      485              485
#       positive    3259     3259             3259
# 5     negative     797      797              797
#       positive   12751    12751            12751

# %%
df[df.score == 0]
# Out:
#                     app                                            content  \
# 6009  Earthquake Alert!  Love app very informative. Is there a way to s...
# 6021  Earthquake Alert!  I live in Indiana daughter is in San Francisco...
#
#       score  sentiment_score sentiment
# 6009      0           0.3612  positive
# 6021      0           0.0000  positive

# %%
df[(df.score == 1)&(df.sentiment == 'positive')]
# Out:
#                   app                                            content  \
# 7      Disaster Alert     Needs dark mode...unable to properly evaluate.
# 24     Disaster Alert  You know I wanted to put your app back on my p...
# 36     Disaster Alert                       Can't open app all the time.
# 38     Disaster Alert  Disaster is a very strong and very descriptive...
# 40     Disaster Alert  7-6-2022 You have not posted one not one earth...
# ...               ...                                                ...
# 27596      Earthquake  It doesn't let you do anything or send seismic...
# 27604      Earthquake  The app takes a long time to warn you about th...
# 27606      Earthquake  There was a tremor in my city Cochabamba Boliv...
# 27618      Earthquake          Unable to focus on one state or zip code!
# 27622      Earthquake  Every time I check I have to re-enter the sear...
#
#        score  sentiment_score sentiment
# 7          1           0.0000  positive
# 24         1           0.5927  positive
# 36         1           0.0000  positive
# 38         1           0.3832  positive
# 40         1           0.0000  positive
# ...      ...              ...       ...
# 27596      1           0.0000  positive
# 27604      1           0.3612  positive
# 27606      1           0.0000  positive
# 27618      1           0.0000  positive
# 27622      1           0.1134  positive
#
# [2808 rows x 5 columns]

# %%
df[(df.score == 1)&(df.sentiment == 'positive')].iloc[1].content
# Out:
# 'You know I wanted to put your app back on my phone but I decided not to after taking a look at it. Because you people chopped it up and changed the whole app. It was much better years ago.'
